# %%
# %%writefile todo_list.txt
# while True:
#     user_action = input("Type add, show, edit, file or exit: ")
#     user_action = user_action.strip()
#     match user_action:
#       case 'add':
#         todo = input("Enter a todo: ")
#         todo_list.append(todo)
#       case 'show':
#         for index, item in enumerate(todo_list):
#           row = f"{index+1}-{item}"
#           print(row)
#       case 'edit':
#         number = int(input("Number of the todo to edit: "))
#         number = number - 1
#         new_todo = input("Enter the new todo: ")
#         todo_list[number] = new_todo
# Out:
# Overwriting todo_list.txt

# %%
todo_list = []

try:
  with open(r'D:\Text\TODO_list.txt','r') as File:
    todos = File.readlines()
except FileNotFoundError:
  pass

while True:
    user_action = input("Type add, show, edit, file or exit: ")
    user_action = user_action.strip()
    match user_action:
      case 'add':
        todo = input("Enter a todo: ")
        todo_list.append(todo)
      case 'show':
        for index, item in enumerate(todo_list):
          row = f"{index+1}-{item}"
          print(row)
      case 'edit':
        number = int(input("Number of the todo to edit: "))
        number = number - 1
        new_todo = input("Enter the new todo: ")
        todo_list[number] = new_todo
      case 'file':
        with open('todo_list.txt','w+') as txt:
          for line in txt:
            print(line, end='')
      case 'exit':
        break
# Out:
# Type add, show, edit, file or exit: add
# Enter a todo: read
# Type add, show, edit, file or exit: add
# Enter a todo: write
# Type add, show, edit, file or exit: add
# Enter a todo: learn
# Type add, show, edit, file or exit: show
# 1-read
# 2-write
# 3-learn
# Type add, show, edit, file or exit: file
# Type add, show, edit, file or exit: exit

# %%
pwd
# Out:
# '/content'
